# %% [markdown]
# # Assigment 2 - Python dictionaries and file I/O
#
# ### Overview
# ------------
#
# The GTEx gene expression dataset consists of samples taken from many human subjects across a variety of tissues. From this dataset we have identified a set of highly-expressed tissue-specific genes. In this exercise, you will be pulling the expressing data for those genes but only in their primary tissue of expression and investigating how much variability exists across the sample population.
#
# Biological Learning Objectives
#
# - Use metadata to associate data with subject or sample traits
# - Use descriptive statistics to make inferences about gene expression heterogeneity
#
# Computational Learning Objectives
#
# - Create and modify a dicitionary
# - Use keys to retrieve values stored in a dictionary
# - Step through each key and value in a dictionary inside a `for` loop
# - Open and read a text file
# - Write to a text file
#
# ### Instructions
# ----------------
#
# - Save a copy of this notebook as `~/qbXX-answers/python_dictionaries.ipynb`.
# - Fill in answers in the available code/markdown cells below.
# - Remember to comment your code to help yourself and us know what each part is intended to do.

# %%
# Use this dictionary for identifying genes of interest and their corresponding tissue of interest

gene_tissue = {
    'ENSG00000042832.11': 'Thyroid',
    'ENSG00000091704.9': 'Pancreas',
    'ENSG00000118245.2': 'Testis',
    'ENSG00000122304.10': 'Testis',
    'ENSG00000122852.14': 'Lung',
    'ENSG00000132693.12': 'Liver',
    'ENSG00000134812.7': 'Stomach',
    'ENSG00000135346.8': 'Pituitary',
    'ENSG00000137392.9': 'Pancreas',
    'ENSG00000142515.14': 'Prostate',
    'ENSG00000142615.7': 'Pancreas',
    'ENSG00000142789.19': 'Pancreas',
    'ENSG00000158874.11': 'Liver',
    'ENSG00000162438.11': 'Pancreas',
    'ENSG00000164816.7': 'Small Intestine - Terminal Ileum',
    'ENSG00000164822.4': 'Small Intestine - Terminal Ileum',
    'ENSG00000168925.10': 'Pancreas',
    'ENSG00000168928.12': 'Pancreas',
    'ENSG00000170890.13': 'Pancreas',
    'ENSG00000171195.10': 'Minor Salivary Gland',
    'ENSG00000172179.11': 'Pituitary',
    'ENSG00000175535.6': 'Pancreas',
    'ENSG00000175646.3': 'Testis',
    'ENSG00000182333.14': 'Stomach',
    'ENSG00000187021.14': 'Pancreas',
    'ENSG00000203784.2': 'Testis',
    'ENSG00000204983.13': 'Pancreas',
    'ENSG00000219073.7': 'Pancreas',
    'ENSG00000229859.9': 'Stomach',
    'ENSG00000240338.5': 'Pancreas',
    'ENSG00000254647.6': 'Pancreas',
    'ENSG00000256713.7': 'Stomach',
    'ENSG00000259384.6': 'Pituitary',
    }

# %% [markdown]
# 1. Load sample metadata from "~/Data/GTEx/GTEx_Analysis_v8_Annotations_SampleAttributesDS.txt" and create a dictionary of sample metadata associating each sample ID with the tissue it was sampled from
#
#     - This file is tab-separated but some values have spaces in their text so make sure to specify `\t` in the `.split()` method
#     - There are several columns in the metadata file, but you only need to be concerned with `SAMPID` and `SMTSD`, the sample ID and sample tissue, respectively
#     - Your dictionary should use the `SAMPID` as the key and `SMTSD` as the value

# %%
metadata_fname = "/Users/cmdb/Data/GTEx/GTEx_Analysis_v8_Annotations_SampleAttributesDS.txt"

meta_dict = {} # Create a dictionary to hold the metadata
for line in open(metadata_fname): # Step through each line of the metadata file
    line = line.strip("\n")
    line = line.split("\t") # Remove the newline character from the line you just read in and split it by the tab character
    if line[0] == "SAMPID":
        continue
    else:
        meta_dict[line[0]] = line[6] # Add the data to your metadata dictionary, using the "SAMPID" column value as the dictionary key and the "SMTSD" column value as the dictionary value

# %% [markdown]
# 2. Load and process the headeer from the GTEx gene expression file "~/Data/GTEx/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz"
#
#     - You have code that will open the file and read in the header line
#     - Create a list of tissues corresponding to the column names in the header, one tissue per column name (don't worry about which the column is a sample ID or not since column names that aren't sample IDs will just get a "missing" label)
#     - For each value in the header, see if it appears in the dictionary of sample ID/tissues that you created in step 1
#     - If the value is in your dictionary, add the corresponding tissue name (the value in dictionary for that sample ID key) to your tissue list
#     - If the value is not in your dictionary, add "missing" to the tissue list

# %%
# Because this file is a gzip-compressed file, you will be using the `gzip` library that comes with python
import gzip

expression_fname = "/Users/cmdb/Data/GTEx/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz"

# Open the file using the gzip library
fs = gzip.open(expression_fname)

# The file starts with two lines of information before the header, so these are skipped using 2 calls of `.readline()` without keeping the returned data
_ = fs.readline()
_ = fs.readline()

# Gzipped text files are read in as byte strings, not regular strings, so you will see that `.decode()` is included after `.readline()` to convert the input into a string
header = fs.readline().decode().rstrip().split("\t")

# Make sure to close the file when you are done reading it
fs.close()

# Create a list to hold the tissue names
tissues = []

for name in header: # Step through each value in the header
    if name in meta_dict:
        tissues.append(meta_dict[name])
    else:
        tissues.append("missing")
    # Check if the value has an entry in the metadata dictionary, adding either the tissue corresponding to that entry or "missing" to your tissues list
# Out:
# ['missing',
#  'missing',
#  'Adipose - Subcutaneous',
#  'Muscle - Skeletal',
#  'Artery - Tibial',
#  'Artery - Coronary',
#  'Heart - Atrial Appendage',
#  'Adipose - Visceral (Omentum)',
#  'Uterus',
#  'Vagina',
#  'Breast - Mammary Tissue',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Minor Salivary Gland',
#  'Brain - Cortex',
#  'Adrenal Gland',
#  'Thyroid',
#  'Lung',
#  'Spleen',
#  'Pancreas',
#  'Esophagus - Muscularis',
#  'Esophagus - Mucosa',
#  'Esophagus - Gastroesophageal Junction',
#  'Stomach',
#  'Adipose - Visceral (Omentum)',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Colon - Sigmoid',
#  'Small Intestine - Terminal Ileum',
#  'Colon - Transverse',
#  'Prostate',
#  'Testis',
#  'Adipose - Subcutaneous',
#  'Muscle - Skeletal',
#  'Nerve - Tibial',
#  'Skin - Sun Exposed (Lower leg)',
#  'Adipose - Subcutaneous',
#  'Muscle - Skeletal',
#  'Artery - Tibial',
#  'Nerve - Tibial',
#  'Heart - Atrial Appendage',
#  'Heart - Left Ventricle',
#  'Thyroid',
#  'Lung',
#  'Spleen',
#  'Testis',
#  'Prostate',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Minor Salivary Gland',
#  'Brain - Cortex',
#  'Brain - Cerebellum',
#  'Cells - Cultured fibroblasts',
#  'Heart - Atrial Appendage',
#  'Thyroid',
#  'Lung',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Testis',
#  'Colon - Transverse',
#  'Adipose - Subcutaneous',
#  'Skin - Sun Exposed (Lower leg)',
#  'Nerve - Tibial',
#  'Muscle - Skeletal',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Adrenal Gland',
#  'Heart - Atrial Appendage',
#  'Heart - Left Ventricle',
#  'Artery - Aorta',
#  'Lung',
#  'Thyroid',
#  'Esophagus - Gastroesophageal Junction',
#  'Esophagus - Mucosa',
#  'Esophagus - Muscularis',
#  'Stomach',
#  'Pancreas',
#  'Adipose - Visceral (Omentum)',
#  'Small Intestine - Terminal Ileum',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Colon - Transverse',
#  'Prostate',
#  'Colon - Sigmoid',
#  'Breast - Mammary Tissue',
#  'Testis',
#  'Nerve - Tibial',
#  'Artery - Tibial',
#  'Muscle - Skeletal',
#  'Adipose - Subcutaneous',
#  'Cells - EBV-transformed lymphocytes',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Lung',
#  'Thyroid',
#  'Adrenal Gland',
#  'Artery - Coronary',
#  'Spleen',
#  'Heart - Atrial Appendage',
#  'Pancreas',
#  'Heart - Left Ventricle',
#  'Adipose - Visceral (Omentum)',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Artery - Aorta',
#  'Breast - Mammary Tissue',
#  'Small Intestine - Terminal Ileum',
#  'Colon - Sigmoid',
#  'Colon - Transverse',
#  'Esophagus - Muscularis',
#  'Esophagus - Mucosa',
#  'Esophagus - Gastroesophageal Junction',
#  'Stomach',
#  'Adipose - Subcutaneous',
#  'Skin - Sun Exposed (Lower leg)',
#  'Artery - Tibial',
#  'Muscle - Skeletal',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Thyroid',
#  'Artery - Aorta',
#  'Lung',
#  'Pancreas',
#  'Adipose - Visceral (Omentum)',
#  'Colon - Transverse',
#  'Adipose - Subcutaneous',
#  'Skin - Sun Exposed (Lower leg)',
#  'Muscle - Skeletal',
#  'Artery - Tibial',
#  'Pituitary',
#  'Brain - Cortex',
#  'Brain - Cerebellum',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Skin - Sun Exposed (Lower leg)',
#  'Adipose - Subcutaneous',
#  'Artery - Tibial',
#  'Nerve - Tibial',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Thyroid',
#  'Adipose - Visceral (Omentum)',
#  'Esophagus - Muscularis',
#  'Esophagus - Gastroesophageal Junction',
#  'Vagina',
#  'Uterus',
#  'Skin - Sun Exposed (Lower leg)',
#  'Muscle - Skeletal',
#  'Pituitary',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Artery - Aorta',
#  'Thyroid',
#  'Heart - Atrial Appendage',
#  'Breast - Mammary Tissue',
#  'Testis',
#  'Colon - Sigmoid',
#  'Muscle - Skeletal',
#  'Skin - Sun Exposed (Lower leg)',
#  'Pituitary',
#  'Brain - Cortex',
#  'Brain - Cerebellum',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Thyroid',
#  'Artery - Aorta',
#  'Heart - Left Ventricle',
#  'Heart - Atrial Appendage',
#  'Lung',
#  'Adipose - Visceral (Omentum)',
#  'Prostate',
#  'Testis',
#  'Colon - Transverse',
#  'Esophagus - Mucosa',
#  'Esophagus - Muscularis',
#  'Stomach',
#  'Muscle - Skeletal',
#  'Skin - Sun Exposed (Lower leg)',
#  'Artery - Tibial',
#  'Pituitary',
#  'Adrenal Gland',
#  'Pancreas',
#  'Small Intestine - Terminal Ileum',
#  'Colon - Sigmoid',
#  'Heart - Atrial Appendage',
#  'Adipose - Visceral (Omentum)',
#  'Colon - Transverse',
#  'Stomach',
#  'Heart - Left Ventricle',
#  'Thyroid',
#  'Lung',
#  'Breast - Mammary Tissue',
#  'Prostate',
#  'Artery - Coronary',
#  'Esophagus - Muscularis',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Testis',
#  'Spleen',
#  'Adipose - Subcutaneous',
#  'Skin - Sun Exposed (Lower leg)',
#  'Nerve - Tibial',
#  'Muscle - Skeletal',
#  'Artery - Tibial',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Thyroid',
#  'Heart - Atrial Appendage',
#  'Skin - Sun Exposed (Lower leg)',
#  'Pituitary',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Brain - Frontal Cortex (BA9)',
#  'Brain - Caudate (basal ganglia)',
#  'Brain - Nucleus accumbens (basal ganglia)',
#  'Brain - Putamen (basal ganglia)',
#  'Brain - Hypothalamus',
#  'Brain - Spinal cord (cervical c-1)',
#  'Skin - Sun Exposed (Lower leg)',
#  'Nerve - Tibial',
#  'Muscle - Skeletal',
#  'Heart - Atrial Appendage',
#  'Thyroid',
#  'Adipose - Visceral (Omentum)',
#  'Esophagus - Gastroesophageal Junction',
#  'Breast - Mammary Tissue',
#  'Small Intestine - Terminal Ileum',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Minor Salivary Gland',
#  'Pituitary',
#  'Brain - Cortex',
#  'Brain - Cerebellum',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Brain - Hippocampus',
#  'Brain - Anterior cingulate cortex (BA24)',
#  'Brain - Caudate (basal ganglia)',
#  'Brain - Nucleus accumbens (basal ganglia)',
#  'Brain - Putamen (basal ganglia)',
#  'Skin - Sun Exposed (Lower leg)',
#  'Adipose - Subcutaneous',
#  'Nerve - Tibial',
#  'Artery - Tibial',
#  'Breast - Mammary Tissue',
#  'Muscle - Skeletal',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Brain - Cerebellum',
#  'Brain - Cortex',
#  'Pituitary',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Adrenal Gland',
#  'Thyroid',
#  'Heart - Left Ventricle',
#  'Artery - Aorta',
#  'Heart - Atrial Appendage',
#  'Lung',
#  'Spleen',
#  'Artery - Coronary',
#  'Pancreas',
#  'Esophagus - Muscularis',
#  'Esophagus - Mucosa',
#  'Esophagus - Gastroesophageal Junction',
#  'Stomach',
#  'Ovary',
#  'Uterus',
#  'Small Intestine - Terminal Ileum',
#  'Vagina',
#  'Colon - Transverse',
#  'Colon - Sigmoid',
#  'Adipose - Visceral (Omentum)',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Adipose - Subcutaneous',
#  'Skin - Sun Exposed (Lower leg)',
#  'Nerve - Tibial',
#  'Artery - Tibial',
#  'Muscle - Skeletal',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Brain - Frontal Cortex (BA9)',
#  'Brain - Cerebellar Hemisphere',
#  'Brain - Caudate (basal ganglia)',
#  'Brain - Nucleus accumbens (basal ganglia)',
#  'Brain - Putamen (basal ganglia)',
#  'Brain - Hypothalamus',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Testis',
#  'Adipose - Visceral (Omentum)',
#  'Thyroid',
#  'Liver',
#  'Heart - Left Ventricle',
#  'Heart - Atrial Appendage',
#  'Artery - Coronary',
#  'Esophagus - Gastroesophageal Junction',
#  'Esophagus - Mucosa',
#  'Esophagus - Muscularis',
#  'Adrenal Gland',
#  'Colon - Sigmoid',
#  'Breast - Mammary Tissue',
#  'Skin - Sun Exposed (Lower leg)',
#  'Muscle - Skeletal',
#  'Pituitary',
#  'Brain - Cerebellum',
#  'Brain - Cortex',
#  'Whole Blood',
#  'Liver',
#  'Adrenal Gland',
#  'Heart - Atrial Appendage',
#  'Artery - Aorta',
#  'Artery - Coronary',
#  'Heart - Left Ventricle',
#  'Lung',
#  'Thyroid',
#  'Esophagus - Gastroesophageal Junction',
#  'Esophagus - Mucosa',
#  'Small Intestine - Terminal Ileum',
#  'Adipose - Visceral (Omentum)',
#  'Colon - Sigmoid',
#  'Colon - Transverse',
#  'Prostate',
#  'Breast - Mammary Tissue',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Testis',
#  'Skin - Sun Exposed (Lower leg)',
#  'Muscle - Skeletal',
#  'Nerve - Tibial',
#  'Artery - Tibial',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Brain - Frontal Cortex (BA9)',
#  'Brain - Cerebellar Hemisphere',
#  'Brain - Caudate (basal ganglia)',
#  'Brain - Nucleus accumbens (basal ganglia)',
#  'Brain - Putamen (basal ganglia)',
#  'Brain - Hypothalamus',
#  'Skin - Sun Exposed (Lower leg)',
#  'Nerve - Tibial',
#  'Thyroid',
#  'Artery - Coronary',
#  'Heart - Atrial Appendage',
#  'Artery - Aorta',
#  'Esophagus - Mucosa',
#  'Esophagus - Muscularis',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Esophagus - Gastroesophageal Junction',
#  'Adipose - Visceral (Omentum)',
#  'Prostate',
#  'Brain - Cerebellum',
#  'Pituitary',
#  'Cells - Cultured fibroblasts',
#  'Brain - Frontal Cortex (BA9)',
#  'Brain - Cerebellar Hemisphere',
#  'Brain - Substantia nigra',
#  'Brain - Anterior cingulate cortex (BA24)',
#  'Brain - Caudate (basal ganglia)',
#  'Brain - Nucleus accumbens (basal ganglia)',
#  'Brain - Putamen (basal ganglia)',
#  'Brain - Hypothalamus',
#  'Brain - Spinal cord (cervical c-1)',
#  'Skin - Sun Exposed (Lower leg)',
#  'Adipose - Subcutaneous',
#  'Breast - Mammary Tissue',
#  'Lung',
#  'Muscle - Skeletal',
#  'Esophagus - Mucosa',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Thyroid',
#  'Brain - Cerebellum',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Brain - Frontal Cortex (BA9)',
#  'Brain - Cerebellar Hemisphere',
#  'Brain - Hippocampus',
#  'Brain - Hypothalamus',
#  'Skin - Sun Exposed (Lower leg)',
#  'Adipose - Subcutaneous',
#  'Muscle - Skeletal',
#  'Nerve - Tibial',
#  'Artery - Tibial',
#  'Breast - Mammary Tissue',
#  'Thyroid',
#  'Lung',
#  'Esophagus - Mucosa',
#  'Testis',
#  'Stomach',
#  'Colon - Sigmoid',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Brain - Cerebellum',
#  'Brain - Cortex',
#  'Pituitary',
#  'Cells - EBV-transformed lymphocytes',
#  'Whole Blood',
#  'Thyroid',
#  'Artery - Aorta',
#  'Adrenal Gland',
#  'Heart - Atrial Appendage',
#  'Artery - Coronary',
#  'Heart - Left Ventricle',
#  'Esophagus - Muscularis',
#  'Esophagus - Mucosa',
#  'Esophagus - Gastroesophageal Junction',
#  'Stomach',
#  'Adipose - Visceral (Omentum)',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Breast - Mammary Tissue',
#  'Colon - Transverse',
#  'Colon - Sigmoid',
#  'Ovary',
#  'Vagina',
#  'Uterus',
#  'Muscle - Skeletal',
#  'Artery - Tibial',
#  'Adipose - Subcutaneous',
#  'Skin - Sun Exposed (Lower leg)',
#  'Cells - EBV-transformed lymphocytes',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Brain - Frontal Cortex (BA9)',
#  'Brain - Cerebellar Hemisphere',
#  'Brain - Substantia nigra',
#  'Brain - Hypothalamus',
#  'Brain - Spinal cord (cervical c-1)',
#  'Lung',
#  'Thyroid',
#  'Adrenal Gland',
#  'Heart - Left Ventricle',
#  'Heart - Atrial Appendage',
#  'Artery - Aorta',
#  'Colon - Sigmoid',
#  'Ovary',
#  'Uterus',
#  'Vagina',
#  'Breast - Mammary Tissue',
#  'Esophagus - Mucosa',
#  'Minor Salivary Gland',
#  'Muscle - Skeletal',
#  'Adipose - Subcutaneous',
#  'Skin - Sun Exposed (Lower leg)',
#  'Artery - Tibial',
#  'Pituitary',
#  'Brain - Cortex',
#  'Brain - Cerebellum',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Adipose - Subcutaneous',
#  'Artery - Tibial',
#  'Muscle - Skeletal',
#  'Thyroid',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Heart - Atrial Appendage',
#  'Testis',
#  'Colon - Sigmoid',
#  'Cells - EBV-transformed lymphocytes',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Adrenal Gland',
#  'Lung',
#  'Spleen',
#  'Liver',
#  'Thyroid',
#  'Esophagus - Mucosa',
#  'Esophagus - Muscularis',
#  'Esophagus - Gastroesophageal Junction',
#  'Pancreas',
#  'Adipose - Visceral (Omentum)',
#  'Stomach',
#  'Small Intestine - Terminal Ileum',
#  'Colon - Transverse',
#  'Colon - Sigmoid',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Prostate',
#  'Breast - Mammary Tissue',
#  'Testis',
#  'Minor Salivary Gland',
#  'Muscle - Skeletal',
#  'Artery - Tibial',
#  'Nerve - Tibial',
#  'Skin - Sun Exposed (Lower leg)',
#  'Adipose - Subcutaneous',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Brain - Hippocampus',
#  'Brain - Substantia nigra',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Artery - Aorta',
#  'Heart - Atrial Appendage',
#  'Heart - Left Ventricle',
#  'Artery - Coronary',
#  'Thyroid',
#  'Adipose - Visceral (Omentum)',
#  'Esophagus - Muscularis',
#  'Colon - Sigmoid',
#  'Testis',
#  'Breast - Mammary Tissue',
#  'Kidney - Cortex',
#  'Muscle - Skeletal',
#  'Adipose - Subcutaneous',
#  'Skin - Sun Exposed (Lower leg)',
#  'Nerve - Tibial',
#  'Artery - Tibial',
#  'Pituitary',
#  'Brain - Cortex',
#  'Whole Blood',
#  'Brain - Hippocampus',
#  'Brain - Substantia nigra',
#  'Brain - Anterior cingulate cortex (BA24)',
#  'Adipose - Visceral (Omentum)',
#  'Thyroid',
#  'Breast - Mammary Tissue',
#  'Adipose - Subcutaneous',
#  'Skin - Sun Exposed (Lower leg)',
#  'Muscle - Skeletal',
#  'Nerve - Tibial',
#  'Pituitary',
#  'Brain - Cortex',
#  'Brain - Cerebellum',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Brain - Frontal Cortex (BA9)',
#  'Brain - Cerebellar Hemisphere',
#  'Brain - Hippocampus',
#  'Brain - Substantia nigra',
#  'Brain - Anterior cingulate cortex (BA24)',
#  'Brain - Caudate (basal ganglia)',
#  'Brain - Nucleus accumbens (basal ganglia)',
#  'Brain - Putamen (basal ganglia)',
#  'Brain - Hypothalamus',
#  'Brain - Spinal cord (cervical c-1)',
#  'Thyroid',
#  'Ovary',
#  'Adrenal Gland',
#  'Pancreas',
#  'Liver',
#  'Lung',
#  'Breast - Mammary Tissue',
#  'Adipose - Visceral (Omentum)',
#  'Artery - Aorta',
#  'Heart - Atrial Appendage',
#  'Heart - Left Ventricle',
#  'Colon - Transverse',
#  'Esophagus - Muscularis',
#  'Esophagus - Mucosa',
#  'Stomach',
#  'Vagina',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Uterus',
#  'Skin - Sun Exposed (Lower leg)',
#  'Muscle - Skeletal',
#  'Nerve - Tibial',
#  'Artery - Tibial',
#  'Pituitary',
#  'Brain - Cerebellum',
#  'Brain - Cortex',
#  'Cells - Cultured fibroblasts',
#  'Brain - Frontal Cortex (BA9)',
#  'Brain - Cerebellar Hemisphere',
#  'Brain - Caudate (basal ganglia)',
#  'Brain - Hypothalamus',
#  'Skin - Sun Exposed (Lower leg)',
#  'Adipose - Subcutaneous',
#  'Muscle - Skeletal',
#  'Nerve - Tibial',
#  'Cells - EBV-transformed lymphocytes',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Lung',
#  'Adipose - Visceral (Omentum)',
#  'Thyroid',
#  'Pancreas',
#  'Artery - Aorta',
#  'Heart - Left Ventricle',
#  'Artery - Coronary',
#  'Small Intestine - Terminal Ileum',
#  'Colon - Transverse',
#  'Colon - Sigmoid',
#  'Esophagus - Muscularis',
#  'Esophagus - Mucosa',
#  'Stomach',
#  'Adrenal Gland',
#  'Ovary',
#  'Vagina',
#  'Uterus',
#  'Breast - Mammary Tissue',
#  'Artery - Tibial',
#  'Muscle - Skeletal',
#  'Adipose - Subcutaneous',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Spleen',
#  'Pancreas',
#  'Adipose - Visceral (Omentum)',
#  'Lung',
#  'Thyroid',
#  'Artery - Aorta',
#  'Heart - Atrial Appendage',
#  'Heart - Left Ventricle',
#  'Skin - Sun Exposed (Lower leg)',
#  'Adipose - Subcutaneous',
#  'Muscle - Skeletal',
#  'Nerve - Tibial',
#  'Artery - Tibial',
#  'Esophagus - Gastroesophageal Junction',
#  'Esophagus - Muscularis',
#  'Esophagus - Mucosa',
#  'Small Intestine - Terminal Ileum',
#  'Colon - Transverse',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Testis',
#  'Breast - Mammary Tissue',
#  'Cells - Cultured fibroblasts',
#  'Thyroid',
#  'Adrenal Gland',
#  'Lung',
#  'Spleen',
#  'Pancreas',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Prostate',
#  'Breast - Mammary Tissue',
#  'Testis',
#  'Esophagus - Mucosa',
#  'Esophagus - Muscularis',
#  'Stomach',
#  'Colon - Transverse',
#  'Small Intestine - Terminal Ileum',
#  'Nerve - Tibial',
#  'Muscle - Skeletal',
#  'Skin - Sun Exposed (Lower leg)',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Brain - Amygdala',
#  'Brain - Caudate (basal ganglia)',
#  'Brain - Nucleus accumbens (basal ganglia)',
#  'Brain - Putamen (basal ganglia)',
#  'Skin - Sun Exposed (Lower leg)',
#  'Muscle - Skeletal',
#  'Adipose - Subcutaneous',
#  'Nerve - Tibial',
#  'Artery - Tibial',
#  'Artery - Aorta',
#  'Lung',
#  'Heart - Atrial Appendage',
#  'Thyroid',
#  'Liver',
#  'Esophagus - Mucosa',
#  'Esophagus - Muscularis',
#  'Esophagus - Gastroesophageal Junction',
#  'Adipose - Visceral (Omentum)',
#  'Stomach',
#  'Testis',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Brain - Cortex',
#  'Brain - Cerebellum',
#  'Pituitary',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Brain - Caudate (basal ganglia)',
#  'Brain - Nucleus accumbens (basal ganglia)',
#  'Brain - Putamen (basal ganglia)',
#  'Muscle - Skeletal',
#  'Artery - Tibial',
#  'Thyroid',
#  'Heart - Atrial Appendage',
#  'Lung',
#  'Liver',
#  'Adipose - Visceral (Omentum)',
#  'Testis',
#  'Minor Salivary Gland',
#  'Breast - Mammary Tissue',
#  'Brain - Cortex',
#  'Brain - Cerebellum',
#  'Pituitary',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Brain - Caudate (basal ganglia)',
#  'Brain - Nucleus accumbens (basal ganglia)',
#  'Skin - Sun Exposed (Lower leg)',
#  'Adipose - Subcutaneous',
#  'Muscle - Skeletal',
#  'Artery - Tibial',
#  'Nerve - Tibial',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Testis',
#  'Heart - Atrial Appendage',
#  'Heart - Left Ventricle',
#  'Lung',
#  'Esophagus - Muscularis',
#  'Esophagus - Gastroesophageal Junction',
#  'Breast - Mammary Tissue',
#  'Colon - Transverse',
#  'Thyroid',
#  'Prostate',
#  'Brain - Cerebellum',
#  'Brain - Cortex',
#  'Pituitary',
#  'Cells - EBV-transformed lymphocytes',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Skin - Sun Exposed (Lower leg)',
#  'Muscle - Skeletal',
#  'Artery - Tibial',
#  'Nerve - Tibial',
#  'Brain - Cerebellum',
#  'Brain - Cortex',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Brain - Cerebellar Hemisphere',
#  'Brain - Caudate (basal ganglia)',
#  'Brain - Nucleus accumbens (basal ganglia)',
#  'Brain - Putamen (basal ganglia)',
#  'Brain - Hypothalamus',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Thyroid',
#  'Liver',
#  'Adipose - Visceral (Omentum)',
#  'Lung',
#  'Kidney - Cortex',
#  'Prostate',
#  'Testis',
#  'Breast - Mammary Tissue',
#  'Esophagus - Muscularis',
#  'Esophagus - Gastroesophageal Junction',
#  'Adipose - Subcutaneous',
#  'Muscle - Skeletal',
#  'Skin - Sun Exposed (Lower leg)',
#  'Brain - Cortex',
#  'Pituitary',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Brain - Hippocampus',
#  'Brain - Amygdala',
#  'Brain - Caudate (basal ganglia)',
#  'Brain - Nucleus accumbens (basal ganglia)',
#  'Brain - Putamen (basal ganglia)',
#  'Brain - Hypothalamus',
#  'Brain - Spinal cord (cervical c-1)',
#  'Heart - Left Ventricle',
#  'Pancreas',
#  'Artery - Aorta',
#  'Heart - Atrial Appendage',
#  'Artery - Coronary',
#  'Esophagus - Muscularis',
#  'Esophagus - Mucosa',
#  'Colon - Sigmoid',
#  'Colon - Transverse',
#  'Breast - Mammary Tissue',
#  'Testis',
#  'Nerve - Tibial',
#  'Muscle - Skeletal',
#  'Adipose - Subcutaneous',
#  'Artery - Tibial',
#  'Pituitary',
#  'Brain - Cortex',
#  'Brain - Cerebellum',
#  'Cells - EBV-transformed lymphocytes',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Adrenal Gland',
#  'Thyroid',
#  'Lung',
#  'Spleen',
#  'Pancreas',
#  'Prostate',
#  'Breast - Mammary Tissue',
#  'Adipose - Visceral (Omentum)',
#  'Testis',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Esophagus - Muscularis',
#  'Esophagus - Mucosa',
#  'Esophagus - Gastroesophageal Junction',
#  'Colon - Transverse',
#  'Small Intestine - Terminal Ileum',
#  'Stomach',
#  'Colon - Sigmoid',
#  'Muscle - Skeletal',
#  'Adipose - Subcutaneous',
#  'Skin - Sun Exposed (Lower leg)',
#  'Nerve - Tibial',
#  'Artery - Tibial',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Thyroid',
#  'Lung',
#  'Artery - Aorta',
#  'Heart - Atrial Appendage',
#  'Adipose - Visceral (Omentum)',
#  'Esophagus - Mucosa',
#  'Esophagus - Muscularis',
#  'Esophagus - Gastroesophageal Junction',
#  'Colon - Transverse',
#  'Spleen',
#  'Colon - Sigmoid',
#  'Ovary',
#  'Uterus',
#  'Breast - Mammary Tissue',
#  'Minor Salivary Gland',
#  'Vagina',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Skin - Sun Exposed (Lower leg)',
#  'Adipose - Subcutaneous',
#  'Muscle - Skeletal',
#  'Nerve - Tibial',
#  'Artery - Tibial',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Artery - Aorta',
#  'Thyroid',
#  'Adipose - Visceral (Omentum)',
#  'Esophagus - Gastroesophageal Junction',
#  'Esophagus - Mucosa',
#  'Esophagus - Muscularis',
#  'Stomach',
#  'Small Intestine - Terminal Ileum',
#  'Minor Salivary Gland',
#  'Colon - Transverse',
#  'Prostate',
#  'Breast - Mammary Tissue',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Testis',
#  'Skin - Sun Exposed (Lower leg)',
#  'Adipose - Subcutaneous',
#  'Muscle - Skeletal',
#  'Nerve - Tibial',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Brain - Frontal Cortex (BA9)',
#  'Brain - Cerebellar Hemisphere',
#  'Brain - Substantia nigra',
#  'Brain - Amygdala',
#  'Brain - Caudate (basal ganglia)',
#  'Brain - Nucleus accumbens (basal ganglia)',
#  'Brain - Putamen (basal ganglia)',
#  'Nerve - Tibial',
#  'Muscle - Skeletal',
#  'Adipose - Subcutaneous',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Breast - Mammary Tissue',
#  'Lung',
#  'Adipose - Visceral (Omentum)',
#  'Colon - Sigmoid',
#  'Brain - Cerebellum',
#  'Brain - Cortex',
#  'Cells - EBV-transformed lymphocytes',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Adrenal Gland',
#  'Pancreas',
#  'Esophagus - Muscularis',
#  'Esophagus - Mucosa',
#  'Esophagus - Gastroesophageal Junction',
#  'Stomach',
#  'Colon - Sigmoid',
#  'Colon - Transverse',
#  'Thyroid',
#  'Artery - Aorta',
#  'Heart - Left Ventricle',
#  'Heart - Atrial Appendage',
#  'Artery - Coronary',
#  'Lung',
#  'Liver',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Adipose - Visceral (Omentum)',
#  'Prostate',
#  'Breast - Mammary Tissue',
#  'Testis',
#  'Muscle - Skeletal',
#  'Adipose - Subcutaneous',
#  'Skin - Sun Exposed (Lower leg)',
#  'Nerve - Tibial',
#  'Artery - Tibial',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Brain - Frontal Cortex (BA9)',
#  'Brain - Cerebellar Hemisphere',
#  'Brain - Amygdala',
#  'Brain - Caudate (basal ganglia)',
#  'Brain - Nucleus accumbens (basal ganglia)',
#  'Brain - Putamen (basal ganglia)',
#  'Brain - Hypothalamus',
#  'Skin - Sun Exposed (Lower leg)',
#  'Adipose - Subcutaneous',
#  'Muscle - Skeletal',
#  'Nerve - Tibial',
#  'Thyroid',
#  'Kidney - Cortex',
#  'Colon - Transverse',
#  'Vagina',
#  'Brain - Cerebellum',
#  'Brain - Cortex',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Brain - Frontal Cortex (BA9)',
#  'Brain - Hippocampus',
#  'Brain - Substantia nigra',
#  'Thyroid',
#  'Lung',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Artery - Aorta',
#  'Heart - Left Ventricle',
#  'Heart - Atrial Appendage',
#  'Esophagus - Muscularis',
#  'Esophagus - Mucosa',
#  'Liver',
#  'Breast - Mammary Tissue',
#  'Small Intestine - Terminal Ileum',
#  'Colon - Transverse',
#  'Prostate',
#  'Testis',
#  'Colon - Sigmoid',
#  'Minor Salivary Gland',
#  'Muscle - Skeletal',
#  'Adipose - Subcutaneous',
#  'Skin - Sun Exposed (Lower leg)',
#  'Artery - Tibial',
#  'Pituitary',
#  'Cells - Cultured fibroblasts',
#  'Brain - Hippocampus',
#  'Brain - Substantia nigra',
#  'Brain - Anterior cingulate cortex (BA24)',
#  'Brain - Caudate (basal ganglia)',
#  'Skin - Sun Exposed (Lower leg)',
#  'Adipose - Subcutaneous',
#  'Muscle - Skeletal',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Brain - Spinal cord (cervical c-1)',
#  'Adipose - Subcutaneous',
#  'Skin - Sun Exposed (Lower leg)',
#  'Muscle - Skeletal',
#  'Nerve - Tibial',
#  'Artery - Tibial',
#  'Thyroid',
#  'Lung',
#  'Artery - Aorta',
#  'Heart - Atrial Appendage',
#  'Artery - Coronary',
#  'Esophagus - Muscularis',
#  'Esophagus - Gastroesophageal Junction',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Cells - EBV-transformed lymphocytes',
#  'Whole Blood',
#  'Spleen',
#  'Thyroid',
#  'Stomach',
#  'Pancreas',
#  'Esophagus - Mucosa',
#  'Esophagus - Muscularis',
#  'Vagina',
#  'Esophagus - Gastroesophageal Junction',
#  'Ovary',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Adipose - Visceral (Omentum)',
#  'Colon - Sigmoid',
#  'Colon - Transverse',
#  'Small Intestine - Terminal Ileum',
#  'Skin - Sun Exposed (Lower leg)',
#  'Muscle - Skeletal',
#  'Artery - Tibial',
#  'Nerve - Tibial',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Brain - Frontal Cortex (BA9)',
#  'Brain - Cerebellar Hemisphere',
#  'Brain - Hippocampus',
#  'Brain - Substantia nigra',
#  'Brain - Anterior cingulate cortex (BA24)',
#  'Brain - Caudate (basal ganglia)',
#  'Brain - Nucleus accumbens (basal ganglia)',
#  'Brain - Putamen (basal ganglia)',
#  'Brain - Hypothalamus',
#  'Lung',
#  'Liver',
#  'Breast - Mammary Tissue',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Testis',
#  'Adipose - Subcutaneous',
#  'Skin - Sun Exposed (Lower leg)',
#  'Muscle - Skeletal',
#  'Artery - Tibial',
#  'Nerve - Tibial',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Brain - Frontal Cortex (BA9)',
#  'Brain - Anterior cingulate cortex (BA24)',
#  'Brain - Hypothalamus',
#  'Brain - Spinal cord (cervical c-1)',
#  'Heart - Atrial Appendage',
#  'Artery - Aorta',
#  'Skin - Sun Exposed (Lower leg)',
#  'Muscle - Skeletal',
#  'Skin - Not Sun Exposed (Suprapubic)',
#  'Lung',
#  'Adipose - Visceral (Omentum)',
#  'Esophagus - Muscularis',
#  'Esophagus - Gastroesophageal Junction',
#  'Breast - Mammary Tissue',
#  'Stomach',
#  'Prostate',
#  'Testis',
#  'Minor Salivary Gland',
#  'Brain - Cortex',
#  'Pituitary',
#  'Whole Blood',
#  'Cells - Cultured fibroblasts',
#  'Adrenal Gland',
#  'Thyroid',
#  'Spleen',
#  'Pancreas',
#  ...]

# %% [markdown]
# 3. Create a list of expression values for each gene in the `gene_tissue` dictionary (given at the start of the exercise), keeping only expression values from the tissue of interest for that gene
#
#     - Since the file is already open, you can keep reading lines from it in, picking up from after the last line read
#     - You will be log-transforming the expression data using the `log2` function from the built-in library `math`
#     - To deal with zeros in expression data, add one before log-transforming expression data

# %%
# Import the log2 function from the math library to transform the expression counts
from math import log2

# Create a dictionary to hold each gene's expression data
gene_expression = {}

# Because this is a large file, for testing purposes you can use only a small portion of the file to test your code
line_counter = 0

# Step through each line of the file
for line in gzip.open(expression_fname):

    # Convert the line into a string from a byte string, remove the newline character at the end, and split it by tab characters
    fields = line.decode().rstrip().split("\t")

    # Check if this line contains data for a gene we are interested in. If not, skip it
    fields = line.decode().rstrip().split("\t")
    if fields[0] not in gene_tissue:
        continue

    # Determine which tissue we care about for this gene
    tissue = gene_tissue[fields[0]]

    # Create a list in the gene expression dictionary to hold the gene's data
    gene_expression[fields[0]] = []

    # Look at each column position, one by one
    for i in range(len(tissues)):

        # For each column, see if it is from the tissue we care about (using the tissues list). If so, add that field to our gene expression list, first transforming it with log2(1 + float(field[i])) 
        if tissues[i] == tissue:
            gene_expression[fields[0]].append(log2(1 + float(fields[i])))# Import the log2 function from the math library to transform the expression counts

# %% [markdown]
# 4. For each gene, calculate the mean, standard deviation, and relative standard deviation and write them to a results file
#
#     - You will be using the `mean` and `stdev` functions from the built-in `statistics` library. Both functions accept a list as their input
#     - Format your results for each gene into a string and write that string to your results file
#     - If you want to organize your results better (completely optional!!), you can save your results in a list and sorting them by tissue type before writing them to a file

# %%
# Load the functions to caculcate the mean and standard deviation from a list
from statistics import stdev, mean

fs = open("gene_analysis.txt", "w") # Open a file to write the results to

meta_tissue = list()

for gene in list(gene_expression.keys()): # Step through each gene and its expression value list
    m = mean(gene_expression[gene])
    std = stdev(gene_expression[gene]) # Calculate the mean and standard deviation of expression
    rv = std / m # Calculate the relative standard deviation (coefficient of variation, std / mean)
    tissue_list = [gene_tissue[gene],str(m),str(std),str(rv)]
    meta_tissue.append(tissue_list)
meta_tissue = sorted(meta_tissue)
for entry in meta_tissue:
    fs.write(f"{entry[0]} {entry[1]} {entry[2]} {entry[3]}\n") # Write the tissue namne, gene name, mean, standard deviation, and relative standard deviation to your results file

fs.close()
# Close your results file

# %% [markdown]
# 5. Looking at your results, answer the following questions
#
#     - Which tissues have low relative variability (rv < 0.2), medium relative variability (0.2 < rv < 0.4), or high relative variability (rv > 0.4)?
#     - Do each of the genes for a given tissue show the same level of relative variability?
#     - Propose an explanation for differences in relative variability you see between tissues based on what you know about their functions.
#     - Were any of the results surpising to you?

# %% [markdown]
# Answers:
# - rv < 0.2: liver, pancreas, pituitary, testis, thyroid; 0.2 < rv < 0.4: liver, lung, minor salivary gland, prostate, small intestine - terminal ileum; rv > 0.4: stomach.
# - No, the two genes for liver have different level of relative variability (one low and the other medium).
# - Tissues with low/medium rv typically are required to be consistent to maintain homeostasis, while the stomach needs to react to outer stimuli, i.e. food, quickly.
# - That pancreas have low rv since they are involved in digestion.
